# %%
import pandas as pd
df =pd.read_csv("/content/archive.zip")

# %%
df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
df.shape
# Out:
# (248, 4)

# %%
df.at[246,'new_cases']
# Out:
# 975.0

# %%
df.loc[243]
# Out:
# date          2020-08-30
# new_cases         1444.0
# new_deaths           1.0
# new_tests        53541.0
# Name: 243, dtype: object

# %%
type(df.loc)
# Out:
# pandas.core.indexing._LocIndexer

# %%
df.tail(4)
# Out:
#            date  new_cases  new_deaths  new_tests
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN

# %%
df_copy= df.copy()

# %%
df_copy
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df.new_tests.first_valid_index()
# Out:
# 111

# %%
df.loc[108:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 108  2020-04-17     3786.0       525.0        NaN
# 109  2020-04-18     3493.0       575.0        NaN
# 110  2020-04-19     3491.0       480.0        NaN
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0

# %%
df.sample(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 191  2020-07-09      193.0        15.0    29947.0
# 58   2020-02-27       78.0         1.0        NaN
# 244  2020-08-31     1365.0         4.0    42583.0
# 149  2020-05-28      584.0       117.0    39838.0
# 122  2020-05-01     1872.0       285.0    43732.0
# 181  2020-06-29      174.0        22.0    15484.0
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# 167  2020-06-15      338.0        44.0    17463.0
# 228  2020-08-15      574.0         3.0    25937.0

# %%
total_cases = df.new_cases.sum()
total_deaths = df.new_deaths.sum()

# %%
print("the number of reported cases is {} and the number of reported death is {}".format( total_cases,total_deaths))
# Out:
# the number of reported cases is 271515.0 and the number of reported death is 35497.0

# %%
death_rate = df.new_deaths.sum() / df.new_cases.sum()

# %%
print("The overall reported death rate in Italy is {:.2f}  . ".format(death_rate))
# Out:
# The overall reported death rate in Italy is 0.13  .

# %%
initial_tests = 935310
total_tests = initial_tests + df.new_tests.sum()

# %%
total_tests
# Out:
# 5214766.0

# %%
positive_rate = total_cases /total_tests

# %%
print('{:.2f} of tests inItaly led to a positive diagnosis.'.format (positive_rate) )
# Out:
# 0.05 of tests inItaly led to a positive diagnosis.

# %% [markdown]
# **QYERYING AND SORTING ROWS**

# %%
high_new_cases = df.new_cases >1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
from IPython.display import display
with pd.option_context("display.max_rows",100):
  display(df[df.new_cases > 1000])
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# 74   2020-03-14     2547.0       252.0        NaN
# 75   2020-03-15     3497.0       173.0        NaN
# 76   2020-03-16     2823.0       370.0        NaN
# 77   2020-03-17     4000.0       347.0        NaN
# 78   2020-03-18     3526.0       347.0        NaN
# 79   2020-03-19     4207.0       473.0        NaN
# 80   2020-03-20     5322.0       429.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 82   2020-03-22     6557.0       795.0        NaN
# 83   2020-03-23     5560.0       649.0        NaN
# 84   2020-03-24     4789.0       601.0        NaN
# 85   2020-03-25     5249.0       743.0        NaN
# 86   2020-03-26     5210.0       685.0        NaN
# ...

# %%
positive_rate
# Out:
# 0.05206657403227681

# %%
high_ratio_df = df[df.new_cases / df.new_tests > positive_rate]

# %%
high_ratio_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0
# 114  2020-04-23     3370.0       437.0    37083.0
# 116  2020-04-25     3021.0       420.0    38676.0
# 117  2020-04-26     2357.0       415.0    24113.0
# 118  2020-04-27     2324.0       260.0    26678.0
# 120  2020-04-29     2091.0       382.0    38589.0
# 123  2020-05-02     1965.0       269.0    31231.0
# 124  2020-05-03     1900.0       474.0    27047.0
# 125  2020-05-04     1389.0       174.0    22999.0
# 128  2020-05-07     1444.0       369.0    13665.0

# %%
df.new_cases / df.new_tests
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 243    0.026970
# 244    0.032055
# 245    0.018311
# 246         NaN
# 247         NaN
# Length: 248, dtype: float64

# %%
df['positive_rate'] = df.new_cases / df.new_tests

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 1    2020-01-01        0.0         0.0        NaN            NaN
# 2    2020-01-02        0.0         0.0        NaN            NaN
# 3    2020-01-03        0.0         0.0        NaN            NaN
# 4    2020-01-04        0.0         0.0        NaN            NaN
# ..          ...        ...         ...        ...            ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055
# 245  2020-09-01      996.0         6.0    54395.0       0.018311
# 246  2020-09-02      975.0         8.0        NaN            NaN
# 247  2020-09-03     1326.0         6.0        NaN            NaN
#
# [248 rows x 5 columns]

# %%
df.drop(columns =['positive_rate'], inplace = True)

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df.sort_values('new_cases',ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 82  2020-03-22     6557.0       795.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 86  2020-03-26     5210.0       685.0        NaN

# %%
df.sort_values('new_deaths' , ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 88  2020-03-28     5959.0       971.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 92  2020-04-01     4053.0       839.0        NaN
# 91  2020-03-31     4050.0       810.0        NaN
# 82  2020-03-22     6557.0       795.0        NaN
# 95  2020-04-04     4585.0       764.0        NaN
# 94  2020-04-03     4668.0       760.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 93  2020-04-02     4782.0       727.0        NaN

# %%
df.sort_values('new_cases').head(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 172  2020-06-20     -148.0        47.0    29875.0
# 0    2019-12-31        0.0         0.0        NaN
# 29   2020-01-29        0.0         0.0        NaN
# 30   2020-01-30        0.0         0.0        NaN
# 32   2020-02-01        0.0         0.0        NaN
# 33   2020-02-02        0.0         0.0        NaN
# 34   2020-02-03        0.0         0.0        NaN
# 36   2020-02-05        0.0         0.0        NaN
# 37   2020-02-06        0.0         0.0        NaN
# 38   2020-02-07        0.0         0.0        NaN

# %%
df.loc[169:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 169  2020-06-17      210.0        34.0    33957.0
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20     -148.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0
# 174  2020-06-22      224.0        24.0    16152.0
# 175  2020-06-23      221.0        23.0    23225.0

# %% [markdown]
# **As we have seen that there is a faulty data inside dataset we can use following method to solve that**
#
# 1.   Replace it with 0
# 2.   Replace it with average of the entire column
# 3.   Replace it with average of the values on the previous & next date
# 4.   Discard the row entirely

# %%
df.at[172,'new_cases'] = (df.at[171, 'new_cases']+ df.at[173,'new_cases']/2)

# %%
df.at[172,'new_cases']
# Out:
# 463.0

# %% [markdown]
# ** WORKING WITH DATES* **

# %%
df.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
df['date'] = pd.to_datetime(df.date)

# %%
df['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
df['year']= pd.DatetimeIndex(df.date).year

# %%
df['month']= pd.DatetimeIndex(df.date).month

# %%
df['day']= pd.DatetimeIndex(df.date).day

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4
# ..         ...        ...         ...        ...   ...    ...  ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3
#
# [248 rows x 7 columns]

# %%
# EXTRACTING THE ROWS FOR MAY
df_may = df[df.month == 5]
df_may
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day
# 122 2020-05-01     1872.0       285.0    43732.0  2020      5    1
# 123 2020-05-02     1965.0       269.0    31231.0  2020      5    2
# 124 2020-05-03     1900.0       474.0    27047.0  2020      5    3
# 125 2020-05-04     1389.0       174.0    22999.0  2020      5    4
# 126 2020-05-05     1221.0       195.0    32211.0  2020      5    5
# 127 2020-05-06     1075.0       236.0    37771.0  2020      5    6
# 128 2020-05-07     1444.0       369.0    13665.0  2020      5    7
# 129 2020-05-08     1401.0       274.0    45428.0  2020      5    8
# 130 2020-05-09     1327.0       243.0    36091.0  2020      5    9
# 131 2020-05-10     1083.0       194.0    31384.0  2020      5   10
# 132 2020-05-11      802.0       165.0    25823.0  2020      5   11
# 133 2020-05-12      744.0       179.0    39620.0  2020      5   12
# 134 2020-05-13     1402.0       172.0    37049.0  2020      5   13
# ...

# %%
# Extract the subset of columns to be aggrated
df_may_metrics = df_may[['new_cases','new_deaths','new_tests']]

# %%
df_may_metrics
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# ...

# %%
# GET THE COLUMNS WISE SUM
may_totals = df_may_metrics.sum()

# %%
may_totals
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
type(may_totals)
# Out:
# pandas.core.series.Series

# %%
df[df.month==5][['new_cases','new_deaths','new_tests']].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# ...

# %%
df.new_cases.mean()
# Out:
# 1097.282258064516

# %%
monthly_groups = df.groupby('month')

# %%
monthly_groups[['new_cases','new_deaths','new_tests']].sum()
# Out:
#        new_cases  new_deaths  new_tests
# month
# 1            3.0         0.0        0.0
# 2          885.0        21.0        0.0
# 3       100851.0     11570.0        0.0
# 4       101852.0     16091.0   419591.0
# 5        29073.0      5658.0  1078720.0
# 6         8383.0      1404.0   830354.0
# 7         6722.0       388.0   797692.0
# 8        21060.0       345.0  1098704.0
# 9         3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4
# ..         ...        ...         ...        ...   ...    ...  ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3
#
# [248 rows x 7 columns]

# %%
df['total_cases'] = df.new_cases.cumsum()

# %%
df['total_deaths'] = df.new_deaths.cumsum()

# %%
df['total_tests'] = df.new_tests.cumsum() +initial_tests

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests  year  month  day  \
# 0   2019-12-31        0.0         0.0        NaN  2019     12   31
# 1   2020-01-01        0.0         0.0        NaN  2020      1    1
# 2   2020-01-02        0.0         0.0        NaN  2020      1    2
# 3   2020-01-03        0.0         0.0        NaN  2020      1    3
# 4   2020-01-04        0.0         0.0        NaN  2020      1    4
# ..         ...        ...         ...        ...   ...    ...  ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020      8   30
# 244 2020-08-31     1365.0         4.0    42583.0  2020      8   31
# 245 2020-09-01      996.0         6.0    54395.0  2020      9    1
# 246 2020-09-02      975.0         8.0        NaN  2020      9    2
# 247 2020-09-03     1326.0         6.0        NaN  2020      9    3
#
#      total_cases  total_deaths  total_tests
# 0            0.0           0.0          NaN
# 1            0.0           0.0          NaN
# ...

# %% [markdown]
# **BASICS PLOTTING WITH PANDAS**

# %%
df.new_cases.plot();

# %%
df.set_index('date',inplace = True)

# %%
df
# Out:
#             new_cases  new_deaths  new_tests  year  month  day  total_cases  \
# date
# 2019-12-31        0.0         0.0        NaN  2019     12   31          0.0
# 2020-01-01        0.0         0.0        NaN  2020      1    1          0.0
# 2020-01-02        0.0         0.0        NaN  2020      1    2          0.0
# 2020-01-03        0.0         0.0        NaN  2020      1    3          0.0
# 2020-01-04        0.0         0.0        NaN  2020      1    4          0.0
# ...               ...         ...        ...   ...    ...  ...          ...
# 2020-08-30     1444.0         1.0    53541.0  2020      8   30     267464.0
# 2020-08-31     1365.0         4.0    42583.0  2020      8   31     268829.0
# 2020-09-01      996.0         6.0    54395.0  2020      9    1     269825.0
# 2020-09-02      975.0         8.0        NaN  2020      9    2     270800.0
# 2020-09-03     1326.0         6.0        NaN  2020      9    3     272126.0
#
#             total_deaths  total_tests
# date
# ...

# %%
df.new_cases.plot()
df.new_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.total_cases.plot()
df.total_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
death_rate = df.total_deaths/df.total_tests
death_rate.plot(title='DeathRate')
# Out:
# <Axes: title={'center': 'DeathRate'}, xlabel='date'>
